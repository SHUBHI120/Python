# %%
import pandas as pd 
a=pd.DataFrame()
print(a)
list=["Anna","Sash","John"]
b=pd.DataFrame(list)
print(b)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#       0
# 0  Anna
# 1  Sash
# 2  John

# %%
import pandas as pd 
a={'Name':["Alex","Jack","Anna"],'Age':[10,15,20]}
b=pd.DataFrame(a)
print(b)
# Out:
#    Name  Age
# 0  Alex   10
# 1  Jack   15
# 2  Anna   20

# %%
import pandas as pd
a={'Name':["Alex","Anna","Sash"],'Age':[20,25,22],'Course':["CSE","IT","CIVIL"],'ID':[101,102,103],'marks':[55,60,68],'CGPA':[9.0,8.5,8.2]}
b=pd.DataFrame(a)
print(b)
# Out:
#    Name  Age Course   ID  marks  CGPA
# 0  Alex   20    CSE  101     55   9.0
# 1  Anna   25     IT  102     60   8.5
# 2  Sash   22  CIVIL  103     68   8.2

# %%
import pandas as pd
student={'Name':["Alex","Anna","Sash"],'Age':[20,25,22]}
c=pd.DataFrame(student)
print("Data before column")
print(c)
Course=["CSE","IT","CIVIL"]
c['Course']=Course
print("Data after add")
print(c)
# Out:
# Data before column
#    Name  Age
# 0  Alex   20
# 1  Anna   25
# 2  Sash   22
# Data after add
#    Name  Age Course
# 0  Alex   20    CSE
# 1  Anna   25     IT
# 2  Sash   22  CIVIL

# %%
import pandas as pd
student={'Name':["Alex","Anna","Sash"],'Age':[20,25,22]}
df=pd.DataFrame(student,index=[1,2,3])
del df['Age']
print(df)
# Out:
#    Name
# 1  Alex
# 2  Anna
# 3  Sash

# %%
import pandas as pd
d={'Name':["Alex","John"],'Age':[22,20]}
df=pd.DataFrame(d,index=['1','2'])
print(df)
df.rename(columns={'Alex':'Peter'},inplace=True)
print(df)
# Out:
#    Name  Age
# 1  Alex   22
# 2  John   20
#    Name  Age
# 1  Alex   22
# 2  John   20

# %%
import pandas as pd
data=pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
data1=data.describe()
data1
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
import pandas as pd
d={'Name':["Alex","John"],'Age':[22,20],'City':["Banaras","Lucknow"]}
e={'Name':["Anna","Jack"],'Age':[21,19],'City':["Agra","Bihar"]}
a=pd.DataFrame(d,index=[0,1,2])
b=pd.dataframe(e,index=[3,4,5])
print(d,"/n/n",e)
frame=[a,b]
b=pd.concat(frame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes, consolidate)
#    1773         blocks = _form_blocks(arrays, names, axes, consolidate)
# -> 1774         mgr = BlockManager(blocks, axes)
#    1775     except ValueError as e:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in __init__(self, blocks, axes, verify_integrity)
#     913
# --> 914             self._verify_integrity()
#     915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in _verify_integrity(self)
#     920             if block.shape[1:] != mgr_shape[1:]:
# --> 921                 raise construction_error(tot_items, block.shape[1:], self.axes)
#     922         if len(self.items) != tot_items:
#
# ...

# %%
#exploratory data 
import pandas as pd
data=pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
data1=data.describe()
data1
data['Age'].value_counts()
# Out:
# 24.0    47
# 25.0    45
# 27.0    41
# 23.0    41
# 26.0    36
# 28.0    31
# 30.0    31
# 29.0    28
# 22.0    26
# 31.0    22
# 20.0    19
# 21.0    19
# 33.0    14
# 32.0    13
# 34.0    10
# 36.0    10
# 35.0     9
# 37.0     4
# 38.0     4
# 40.0     3
# 39.0     2
# 19.0     2
# Name: Age, dtype: int64

# %%
#data visualistion (MALPLOTLIB + PANDAS)
import pandas as pd
import matplotlib.pyplot as plt
data=[['E001','M',34,123,'normal',350],
      ['E002','F',42,246,'overweight',450],
      ['E003','M',32,126,'normal',302],
      ['E004','F',30,220,'overweight',303],
      ['E005','M',45,152,'normal',288],
      ['E006','M',40,257,'overweight',246],
      ['E007','F',33,248,'normal',355],
      ['E008','M',46,230,'overweight',230]]
df=pd.DataFrame(data,columns=['Empid','Gender','Age','Sales','BMI','Income'])
df.hist()
df.plot.bar()
plt.show()
