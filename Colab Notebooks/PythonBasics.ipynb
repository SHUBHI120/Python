# %%
#square root 
a=int(input("Enter a number:"))
print((a**0.5))
# Out:
# Enter a number:81
# 9.0

# %%
#swapping of two variables 
a=25
b=23
temp=a
a=b
b=temp
print(b)
print(a)
# Out:
# 25
# 23

# %%
#odd even
a=int(input("Enter a number:"))
if(a%2==0):
  print("number is even.")
else:
    print("number is odd.")
# Out:
# Enter a number:24
# number is even.

# %%
a=int(input("Enter a number:"))
for i in range(1,11):
  print(a, "x", i,'=',a*i)
# Out:
# Enter a number:2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))

if(a>b):
  print("a is greater than b")
elif(a==b):
  print("a is equal to b")
else:
  print("a is less than b")
# Out:
# Enter a number:12
# Enter a number:22
# a is less than b

# %%
import random as rm
print(rm.randint(0,20))
# Out:
# 2
