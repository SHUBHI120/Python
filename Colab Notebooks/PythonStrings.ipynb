# %%
print("Hello")
# Out:
# Hello

# %%
Sno1=int(input("enter marks of 1 subject:"))
Sno2=int(input("enter marks of 2 subject:"))
Sno3=int(input("enter marks of 3 subject:"))
Sno4=int(input("enter marks of 4 subject:"))
Sno5=int(input("enter marks of 5 subject:"))
avg=(Sno1+Sno2+Sno3+Sno4+Sno5)/5

if(avg>=90):
   print("Grade A")
elif(avg>=80 and avg<90):
   print("Grade B")
elif(avg>=70 and avg<80):
   print("Grade C")
elif(avg>=60 and avg<70):
   print("Grade D")
# Out:
# enter marks of 1 subject:99
# enter marks of 2 subject:99
# enter marks of 3 subject:99
# enter marks of 4 subject:99
# enter marks of 5 subject:99
# Grade A

# %%
num=int(input("enter number to check:"))

if(num>=0):
  print("Number is positive.")
elif(num<0):
  print("Number is negative.")
# Out:
# enter number to check:-25
# Number is negative.

# %%
Str=(input("Enter a string:"))
a=Str[0:]
print(a)
b=Str[1:5]
print(b)
# Out:
# Enter a string:SHUBHANGI
# SHUBHANGI
# HUBH

# %%
V=(input("Enter a string:"))
I=0
for I in V:
if(V=='a' or V=='e' or V=='i' or V=='o' or V=='u'):
  print("vowel")
elif():
  print("consonent")
# Out:
# Enter a string:shubhangi

# %%
Str=(input("Enter a string:"))
Str=Str.replace('A','@')
Str=Str.replace('a','@')
print("modified string:",Str)
# Out:
# Enter a string:Shubhangi
# modified string: Shubh@ngi
